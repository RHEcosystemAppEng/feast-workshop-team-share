# %% [markdown]
# ## Setting up the feast

# %% [markdown]
# Feast supports the great expectations library to validate the quality of the feature data. If you have not installed these libraries already please install them.

# %%
# !pip install 'feast[ge]'
# Out:
# Requirement already satisfied: feast[ge] in /usr/local/anaconda3/lib/python3.11/site-packages (0.35.0)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (8.1.7)
# Requirement already satisfied: colorama<1,>=0.3.9 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.4.6)
# Requirement already satisfied: dill~=0.3.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.3.6)
# Requirement already satisfied: fastavro<2,>=1.1.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.9.3)
# Requirement already satisfied: grpcio<2,>=1.56.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.60.0)
# Requirement already satisfied: grpcio-tools<2,>=1.56.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.60.0)
# Requirement already satisfied: grpcio-reflection<2,>=1.56.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.60.0)
# Requirement already satisfied: grpcio-health-checking<2,>=1.56.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.60.0)
# Requirement already satisfied: mypy-protobuf==3.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (3.1.2)
# Requirement already satisfied: jsonschema in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (4.19.2)
# Requirement already satisfied: mmh3 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (4.1.0)
# Requirement already satisfied: numpy<1.25,>=1.22 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.24.4)
# Requirement already satisfied: pandas<2,>=1.4.3 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.5.3)
# Requirement already satisfied: pandavro~=1.5.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.5.2)
# Requirement already satisfied: protobuf<4.23.4,>3.20 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (4.23.3)
# Requirement already satisfied: proto-plus<2,>=1.20.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.23.0)
# Requirement already satisfied: pyarrow>=4 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (11.0.0)
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.10.12)
# Requirement already satisfied: pygments<3,>=2.12.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from feast[ge]) (2.18.0)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (6.0.1)
# Requirement already satisfied: requests in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (2.31.0)
# Requirement already satisfied: SQLAlchemy[mypy]<2,>1 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (1.4.51)
# Requirement already satisfied: tabulate<1,>=0.8.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.9.0)
# Requirement already satisfied: tenacity<9,>=7 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (8.2.2)
# Requirement already satisfied: toml<1,>=0.10.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.10.2)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (4.65.0)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (2.13.3)
# Requirement already satisfied: fastapi<0.100,>=0.68.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.99.1)
# Requirement already satisfied: uvicorn[standard]<1,>=0.14.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.27.0.post1)
# Requirement already satisfied: gunicorn in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (21.2.0)
# Requirement already satisfied: dask>=2021.1.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (2023.11.0)
# Requirement already satisfied: bowler in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.9.0)
# Requirement already satisfied: httpx>=0.23.3 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (0.26.0)
# Requirement already satisfied: importlib-resources<7,>=6.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (6.1.1)
# Requirement already satisfied: importlib-metadata<7,>=6.8.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from feast[ge]) (6.11.0)
# Collecting great-expectations<0.16.0,>=0.15.41 (from feast[ge])
#   Obtaining dependency information for great-expectations<0.16.0,>=0.15.41 from https://files.pythonhosted.org/packages/1a/c7/d0038e9c14c207fc4e5103dbd3339c2e4f2865904d28211a172d474dcec6/great_expectations-0.15.50-py3-none-any.whl.metadata
#   Downloading great_expectations-0.15.50-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: types-protobuf>=3.17.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from mypy-protobuf==3.1->feast[ge]) (4.24.0.20240106)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from dask>=2021.1.0->feast[ge]) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from dask>=2021.1.0->feast[ge]) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from dask>=2021.1.0->feast[ge]) (24.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from dask>=2021.1.0->feast[ge]) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from dask>=2021.1.0->feast[ge]) (0.12.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from fastapi<0.100,>=0.68.0->feast[ge]) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from fastapi<0.100,>=0.68.0->feast[ge]) (4.12.1)
# Collecting altair<4.2.1,>=4.0.0 (from great-expectations<0.16.0,>=0.15.41->feast[ge])
#   Obtaining dependency information for altair<4.2.1,>=4.0.0 from https://files.pythonhosted.org/packages/0a/fb/56aaac0c69d106e380ff868cd5bb6cccacf2b8917a8527532bc89804a52e/altair-4.2.0-py3-none-any.whl.metadata
#   Downloading altair-4.2.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (41.0.7)
# Requirement already satisfied: Ipython>=7.16.3 in /Users/lrangine/.local/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (8.25.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (8.0.4)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.32)
# Collecting makefun<2,>=1.7.0 (from great-expectations<0.16.0,>=0.15.41->feast[ge])
#   Obtaining dependency information for makefun<2,>=1.7.0 from https://files.pythonhosted.org/packages/47/45/51d50062d95a0c2fd8f5f1cc8849878ea5c76d2f6a049a0b9d449272e97f/makefun-1.15.2-py2.py3-none-any.whl.metadata
#   Downloading makefun-1.15.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting marshmallow<4.0.0,>=3.7.1 (from great-expectations<0.16.0,>=0.15.41->feast[ge])
#   Obtaining dependency information for marshmallow<4.0.0,>=3.7.1 from https://files.pythonhosted.org/packages/96/d7/f318261e6ccbba86bdf626e07cd850981508fdaec52cfcdc4ac1030327ab/marshmallow-3.21.3-py3-none-any.whl.metadata
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.0.4)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (5.9.2)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (7.0.6)
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lrangine/.local/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (2023.3.post1)
# Collecting ruamel.yaml<0.17.18,>=0.16 (from great-expectations<0.16.0,>=0.15.41->feast[ge])
#   Obtaining dependency information for ruamel.yaml<0.17.18,>=0.16 from https://files.pythonhosted.org/packages/c7/75/729b63cd0de2316c8bb789ff2c557d9732a5aeb900c5539ae74db41ba562/ruamel.yaml-0.17.17-py3-none-any.whl.metadata
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.11.4)
# Collecting tzlocal>=1.2 (from great-expectations<0.16.0,>=0.15.41->feast[ge])
#   Obtaining dependency information for tzlocal>=1.2 from https://files.pythonhosted.org/packages/97/3f/c4c51c55ff8487f2e6d0e618dba917e3c3ee2caae6cf0fbb59c9b1876f2e/tzlocal-5.2-py3-none-any.whl.metadata
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.26.18)
# Requirement already satisfied: setuptools in /usr/local/anaconda3/lib/python3.11/site-packages (from grpcio-tools<2,>=1.56.2->feast[ge]) (69.0.3)
# Requirement already satisfied: anyio in /usr/local/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.3->feast[ge]) (3.5.0)
# Requirement already satisfied: certifi in /usr/local/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.3->feast[ge]) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.3->feast[ge]) (1.0.2)
# Requirement already satisfied: idna in /usr/local/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.3->feast[ge]) (3.4)
# Requirement already satisfied: sniffio in /usr/local/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.3->feast[ge]) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.3->feast[ge]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/anaconda3/lib/python3.11/site-packages (from importlib-metadata<7,>=6.8.0->feast[ge]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from Jinja2<4,>=2->feast[ge]) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from jsonschema->feast[ge]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/anaconda3/lib/python3.11/site-packages (from jsonschema->feast[ge]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from jsonschema->feast[ge]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from jsonschema->feast[ge]) (0.10.6)
# Requirement already satisfied: six>=1.9 in /Users/lrangine/.local/lib/python3.11/site-packages (from pandavro~=1.5.0->feast[ge]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/anaconda3/lib/python3.11/site-packages (from requests->feast[ge]) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[mypy]<2,>1->feast[ge]) (3.0.1)
# Requirement already satisfied: sqlalchemy2-stubs in /usr/local/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[mypy]<2,>1->feast[ge]) (0.0.2a38)
# Requirement already satisfied: mypy>=0.910 in /usr/local/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[mypy]<2,>1->feast[ge]) (1.8.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]<1,>=0.14.0->feast[ge]) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]<1,>=0.14.0->feast[ge]) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]<1,>=0.14.0->feast[ge]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]<1,>=0.14.0->feast[ge]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]<1,>=0.14.0->feast[ge]) (12.0)
# Requirement already satisfied: fissix in /usr/local/anaconda3/lib/python3.11/site-packages (from bowler->feast[ge]) (21.11.13)
# Requirement already satisfied: moreorless>=0.2.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from bowler->feast[ge]) (0.4.0)
# Requirement already satisfied: volatile in /usr/local/anaconda3/lib/python3.11/site-packages (from bowler->feast[ge]) (2.1.0)
# Requirement already satisfied: entrypoints in /usr/local/anaconda3/lib/python3.11/site-packages (from altair<4.2.1,>=4.0.0->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/anaconda3/lib/python3.11/site-packages (from cryptography>=3.2->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.16.0)
# Requirement already satisfied: decorator in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (3.0.46)
# Requirement already satisfied: stack-data in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/lrangine/.local/lib/python3.11/site-packages (from Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (3.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/anaconda3/lib/python3.11/site-packages (from jsonpatch>=1.22->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.1)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from mypy>=0.910->SQLAlchemy[mypy]<2,>1->feast[ge]) (1.0.0)
# Requirement already satisfied: fastjsonschema in /usr/local/anaconda3/lib/python3.11/site-packages (from nbformat>=5.0->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.16.2)
# Requirement already satisfied: jupyter-core in /usr/local/anaconda3/lib/python3.11/site-packages (from nbformat>=5.0->great-expectations<0.16.0,>=0.15.41->feast[ge]) (5.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.25.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (6.4)
# Requirement already satisfied: locket in /usr/local/anaconda3/lib/python3.11/site-packages (from partd>=1.2.0->dask>=2021.1.0->feast[ge]) (1.0.0)
# Requirement already satisfied: appdirs in /usr/local/anaconda3/lib/python3.11/site-packages (from fissix->bowler->feast[ge]) (1.4.4)
# Requirement already satisfied: pycparser in /usr/local/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.21)
# Requirement already satisfied: appnope in /Users/lrangine/.local/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/lrangine/.local/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/lrangine/.local/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (8.6.0)
# Requirement already satisfied: nest-asyncio in /Users/lrangine/.local/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/lrangine/.local/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations<0.16.0,>=0.15.41->feast[ge]) (26.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/lrangine/.local/lib/python3.11/site-packages (from jedi>=0.16->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat>=5.0->great-expectations<0.16.0,>=0.15.41->feast[ge]) (3.10.0)
# Requirement already satisfied: argon2-cffi in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (7.10.0)
# Requirement already satisfied: overrides in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (7.4.0)
# Requirement already satisfied: prometheus-client in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.17.1)
# Requirement already satisfied: websocket-client in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.9.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lrangine/.local/lib/python3.11/site-packages (from pexpect>4.3->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/lrangine/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from stack-data->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/lrangine/.local/lib/python3.11/site-packages (from stack-data->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/lrangine/.local/lib/python3.11/site-packages (from stack-data->Ipython>=7.16.3->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.2.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (4.1.0)
# Requirement already satisfied: defusedxml in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/anaconda3/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/anaconda3/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (0.5.1)
# Collecting fqdn (from jsonschema->feast[ge])
#   Obtaining dependency information for fqdn from https://files.pythonhosted.org/packages/cf/58/8acf1b3e91c58313ce5cb67df61001fc9dcd21be4fadb76c1a2d540e09ed/fqdn-1.5.1-py3-none-any.whl.metadata
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema->feast[ge])
#   Obtaining dependency information for isoduration from https://files.pythonhosted.org/packages/7b/55/e5326141505c5d5e34c5e0935d2908a74e4561eca44108fbfb9c13d2911a/isoduration-20.11.0-py3-none-any.whl.metadata
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting uri-template (from jsonschema->feast[ge])
#   Obtaining dependency information for uri-template from https://files.pythonhosted.org/packages/e7/00/3fca040d7cf8a32776d3d81a00c8ee7457e00f80c649f1e4a863c8321ae9/uri_template-1.3.0-py3-none-any.whl.metadata
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema->feast[ge])
#   Obtaining dependency information for webcolors>=1.11 from https://files.pythonhosted.org/packages/3b/45/0c30e10a2ac52606476394e4ba11cf3b12ba5823e7fbb9167f80eee6000a/webcolors-24.6.0-py3-none-any.whl.metadata
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4.10->great-expectations<0.16.0,>=0.15.41->feast[ge]) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/anaconda3/lib/python3.11/site-packages (from isoduration->jsonschema->feast[ge]) (1.2.3)
# Downloading great_expectations-0.15.50-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 3.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading makefun-1.15.2-py2.py3-none-any.whl (22 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 1.4 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 2.0 MB/s eta 0:00:003.7 MB/s eta 0:00:01
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: makefun, webcolors, uri-template, tzlocal, ruamel.yaml, marshmallow, fqdn, isoduration, altair, great-expectations
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.17.21
#     Uninstalling ruamel.yaml-0.17.21:
#       Successfully uninstalled ruamel.yaml-0.17.21
# Successfully installed altair-4.2.0 fqdn-1.5.1 great-expectations-0.15.50 isoduration-20.11.0 makefun-1.15.2 marshmallow-3.21.3 ruamel.yaml-0.17.17 tzlocal-5.2 uri-template-1.3.0 webcolors-24.6.0

# %% [markdown]
# ## Setting up the feast repo and features

# %% [markdown]
# As part of this excercise, we are going to use `trips_stats.parquet` and `entities.parquet` files as our data sources.

# %% [markdown]
# We are going to configure the feast repo and define features.

# %%
import pyarrow.parquet
import pandas as pd

from feast import FeatureView, Entity, FeatureStore, Field, BatchFeatureView
from feast.types import Float64, Int64
from feast.value_type import ValueType
from feast.data_format import ParquetFormat
from feast.on_demand_feature_view import on_demand_feature_view
from feast.infra.offline_stores.file_source import FileSource
from feast.infra.offline_stores.file import SavedDatasetFileStorage
from datetime import timedelta
# Out:
# /usr/local/anaconda3/lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
batch_source = FileSource(
    timestamp_field="day",
    path="trips_stats.parquet",  # using parquet file that we created on previous step
    file_format=ParquetFormat()
)

# %%
taxi_entity = Entity(name='taxi', join_keys=['taxi_id'])

# %%
trips_stats_fv = BatchFeatureView(
    name='trip_stats',
    entities=[taxi_entity],
    schema=[
        Field(name="total_miles_travelled", dtype=Float64),
        Field(name="total_trip_seconds", dtype=Float64),
        Field(name="total_earned", dtype=Float64),
        Field(name="trip_count", dtype=Int64),

    ],
    ttl=timedelta(seconds=86400),
    source=batch_source,
)
# Out:
# /usr/local/anaconda3/lib/python3.11/site-packages/feast/batch_feature_view.py:72: RuntimeWarning: Batch feature views are experimental features in alpha development. Some functionality may still be unstable so functionality can change in the future.
#   warnings.warn(

# %%
@on_demand_feature_view(
    sources=[
      trips_stats_fv,
    ],
    schema=[
        Field(name="avg_fare", dtype=Float64),
        Field(name="avg_speed", dtype=Float64),
        Field(name="avg_trip_seconds", dtype=Float64),
        Field(name="earned_per_hour", dtype=Float64),
    ]
)
def on_demand_stats(inp: pd.DataFrame) -> pd.DataFrame:
    out = pd.DataFrame()
    out["avg_fare"] = inp["total_earned"] / inp["trip_count"]
    out["avg_speed"] = 3600 * inp["total_miles_travelled"] / inp["total_trip_seconds"]
    out["avg_trip_seconds"] = inp["total_trip_seconds"] / inp["trip_count"]
    out["earned_per_hour"] = 3600 * inp["total_earned"] / inp["total_trip_seconds"]
    return out

# %%
store = FeatureStore(".")  # using feature_store.yaml that stored in the same directory

# %%
store.apply([taxi_entity, trips_stats_fv, on_demand_stats])  # writing to the registry
# Out:
# /usr/local/anaconda3/lib/python3.11/site-packages/feast/feature_store.py:565: RuntimeWarning: On demand feature view is an experimental feature. This API is stable, but the functionality does not scale well for offline retrieval
#   warnings.warn(

# %% [markdown]
# Now we have completed setting up the feast repo and features.

# %% [markdown]
# ## Generating Training Dataset

# %% [markdown]
# We are going to generate the data from `entities.parquet` and load into the feast repo we have created into the previous step.

# %%
taxi_ids = pyarrow.parquet.read_table("entities.parquet").to_pandas()

# %% [markdown]
# Generating range of timestamps with daily frequency:

# %%
timestamps = pd.DataFrame()
timestamps["event_timestamp"] = pd.date_range("2019-06-01", "2019-07-01", freq='D')

# %% [markdown]
# Cross merge (aka relation multiplication) produces entity dataframe with each taxi_id repeated for each timestamp:

# %%
entity_df = pd.merge(taxi_ids, timestamps, how='cross')
entity_df
# Out:
#                                                   taxi_id event_timestamp
# 0       91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2019-06-01
# 1       91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2019-06-02
# 2       91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2019-06-03
# 3       91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2019-06-04
# 4       91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2019-06-05
# ...                                                   ...             ...
# 156979  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2019-06-27
# 156980  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2019-06-28
# 156981  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2019-06-29
# 156982  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2019-06-30
# 156983  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2019-07-01
#
# [156984 rows x 2 columns]

# %% [markdown]
# Retrieving historical features for resulting entity dataframe and persisting output as a saved dataset:

# %%
job = store.get_historical_features(
    entity_df=entity_df,
    features=[
        "trip_stats:total_miles_travelled",
        "trip_stats:total_trip_seconds",
        "trip_stats:total_earned",
        "trip_stats:trip_count",
        "on_demand_stats:avg_fare",
        "on_demand_stats:avg_trip_seconds",
        "on_demand_stats:avg_speed",
        "on_demand_stats:earned_per_hour",
    ]
)

store.create_saved_dataset(
    from_=job,
    name='my_training_ds',
    storage=SavedDatasetFileStorage(path='my_training_ds.parquet')
)
# Out:
# /usr/local/anaconda3/lib/python3.11/site-packages/feast/feature_store.py:1181: RuntimeWarning: Saving dataset is an experimental feature. This API is unstable and it could and most probably will be changed in the future. We do not guarantee that future changes will maintain backward compatibility.
#   warnings.warn(
# <SavedDataset(name = my_training_ds, features = ['trip_stats:total_miles_travelled', 'trip_stats:total_trip_seconds', 'trip_stats:total_earned', 'trip_stats:trip_count', 'on_demand_stats:avg_fare', 'on_demand_stats:avg_trip_seconds', 'on_demand_stats:avg_speed', 'on_demand_stats:earned_per_hour'], join_keys = ['taxi_id'], storage = <feast.infra.offline_stores.file_source.SavedDatasetFileStorage object at 0x12a785b10>, full_feature_names = False, tags = {}, feature_service_name = None, _retrieval_job = <feast.infra.offline_stores.file.FileRetrievalJob object at 0x12a7808d0>, min_event_timestamp = 2019-06-01 00:00:00+00:00, max_event_timestamp = 2019-07-01 00:00:00+00:00, created_timestamp = 2024-06-18 18:51:39.099184, last_updated_timestamp = 2024-06-18 18:51:39.099184)>

# %% [markdown]
# ## Developing dataset profiler(AKA setting up the data Validation Rules)

# %% [markdown]
# Dataset profiler is a function that accepts dataset and generates set of its characteristics. This charasteristics will be then used to evaluate (validate) next datasets.

# %% [markdown]
# **Important: datasets are not compared to each other! Feast use a reference dataset and a profiler function to generate a reference profile. This profile will be then used during validation of the tested dataset.**

# %%
import numpy as np

from feast.dqm.profilers.ge_profiler import ge_profiler

from great_expectations.core.expectation_suite import ExpectationSuite
from great_expectations.dataset import PandasDataset
# Out:
# /usr/local/anaconda3/lib/python3.11/site-packages/great_expectations/util.py:55: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import Distribution
# /usr/local/anaconda3/lib/python3.11/site-packages/pkg_resources/__init__.py:2868: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/anaconda3/lib/python3.11/site-packages/pkg_resources/__init__.py:2868: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/anaconda3/lib/python3.11/site-packages/pkg_resources/__init__.py:2868: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('zope')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)

# %% [markdown]
# Loading saved dataset first and exploring the data:

# %%
ds = store.get_saved_dataset('my_training_ds')
ds.to_df()
# Out:
#         earned_per_hour  total_trip_seconds  total_miles_travelled  avg_speed  \
# 0             45.559701               16080                  69.50  15.559701
# 1             36.219512                7380                  15.80   7.707317
# 2             54.212598                7620                  38.50  18.188976
# 3             45.000000                5660                  20.22  12.860777
# 4             53.783319                6978                  34.49  17.793637
# ...                 ...                 ...                    ...        ...
# 119803        76.369295                4820                  36.98  27.619917
# 119804        52.677165                7620                  29.00  13.700787
# 119805        54.649682                9420                  31.00  11.847134
# 119806        73.770492                4941                  37.86  27.584699
# 119807        67.500000               11640                  58.90  18.216495
#
#                  event_timestamp  \
# 0      2019-06-01 00:00:00+00:00
# 1      2019-06-01 00:00:00+00:00
# 2      2019-06-01 00:00:00+00:00
# 3      2019-06-01 00:00:00+00:00
# 4      2019-06-01 00:00:00+00:00
# ...                          ...
# 119803 2019-07-01 00:00:00+00:00
# 119804 2019-07-01 00:00:00+00:00
# 119805 2019-07-01 00:00:00+00:00
# 119806 2019-07-01 00:00:00+00:00
# 119807 2019-07-01 00:00:00+00:00
#
#                                                   taxi_id  avg_trip_seconds  \
# 0       d13c5aaa066f94b4927779ed24cd313b0c686f03407095...       2010.000000
# 1       33164e16dd29b1c58cd15cce31df4bfcb75d9903cb66de...       1476.000000
# 2       226fe0b00be42932bdff81bc0b318b883bfbf15dd48093...       1270.000000
# 3       5a5bed1b5ced617d0594007d591f10bbbca354d50b19ca...       1415.000000
# 4       b7f7dbb452c0fb980a0f2050a146147c1006fe5f34e3b0...       1395.600000
# ...                                                   ...               ...
# 119803  961263722c1beadafef2355412d672acac35e4054f6aaa...       1205.000000
# 119804  8b07f9156e568a37d362463c84dbd1118b4eeb753bae50...        692.727273
# 119805  a112879f10892d5c698ce150af17aa28615b6d005ca749...        588.750000
# 119806  68fe14b9fc2d53de5ac349d47f80f43fea895e201a31e3...       1647.000000
# 119807  6933327f9cc740e893a882282f7d06460207d6d4e084b3...        554.285714
#
#          avg_fare  trip_count  total_earned
# 0       25.437500           8        203.50
# 1       14.850000           5         74.25
# 2       19.125000           6        114.75
# 3       17.687500           4         70.75
# 4       20.850000           5        104.25
# ...           ...         ...           ...
# 119803  25.562500           4        102.25
# 119804  10.136364          11        111.50
# 119805   8.937500          16        143.00
# 119806  33.750000           3        101.25
# 119807  10.392857          21        218.25
#
# [119808 rows x 10 columns]

# %% [markdown]
# Feast uses [Great Expectations](https://docs.greatexpectations.io/docs/home/) as a validation engine and [ExpectationSuite](https://docs.greatexpectations.io/docs/oss/guides/validation/validate_data_lp/) as a dataset's profile. Hence, we need to develop a function that will generate ExpectationSuite. This function will receive instance of PandasDataset (wrapper around pandas.DataFrame) so we can utilize both Pandas DataFrame API and some helper functions from PandasDataset during profiling.

# %%
DELTA = 0.1  # controlling allowed window in fraction of the value on scale [0, 1]

@ge_profiler
def stats_profiler(ds: PandasDataset) -> ExpectationSuite:
    # simple checks on data consistency
    ds.expect_column_values_to_be_between(
        "avg_speed",
        min_value=0,
        max_value=60,
        mostly=0.99  # allow some outliers
    )

    ds.expect_column_values_to_be_between(
        "total_miles_travelled",
        min_value=0,
        max_value=500,
        mostly=0.99  # allow some outliers
    )

    # expectation of means based on observed values
    observed_mean = ds.trip_count.mean()
    ds.expect_column_mean_to_be_between("trip_count",
                                        min_value=observed_mean * (1 - DELTA),
                                        max_value=observed_mean * (1 + DELTA))

    observed_mean = ds.earned_per_hour.mean()
    ds.expect_column_mean_to_be_between("earned_per_hour",
                                        min_value=observed_mean * (1 - DELTA),
                                        max_value=observed_mean * (1 + DELTA))


    # expectation of quantiles
    qs = [0.5, 0.75, 0.9, 0.95]
    observed_quantiles = ds.avg_fare.quantile(qs)

    ds.expect_column_quantile_values_to_be_between(
        "avg_fare",
        quantile_ranges={
            "quantiles": qs,
            "value_ranges": [[None, max_value] for max_value in observed_quantiles]
        })

    return ds.get_expectation_suite()

# %% [markdown]
# Testing our profiler function:

# %%
ds.get_profile(profiler=stats_profiler)
# Out:
# <GEProfile with expectations: [
#   {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "avg_speed",
#       "min_value": 0,
#       "max_value": 60,
#       "mostly": 0.99
#     },
#     "meta": {}
#   },
#   {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "total_miles_travelled",
#       "min_value": 0,
#       "max_value": 500,
#       "mostly": 0.99
#     },
#     "meta": {}
#   },
#   {
#     "expectation_type": "expect_column_mean_to_be_between",
#     "kwargs": {
#       "column": "trip_count",
#       "min_value": 10.387244591346153,
#       "max_value": 12.695521167200855
#     },
#     "meta": {}
#   },
#   {
#     "expectation_type": "expect_column_mean_to_be_between",
#     "kwargs": {
#       "column": "earned_per_hour",
#       "min_value": 52.32062497564023,
#       "max_value": 63.9474305257825
#     },
#     "meta": {}
#   },
#   {
#     "expectation_type": "expect_column_quantile_values_to_be_between",
#     "kwargs": {
#       "column": "avg_fare",
#       "quantile_ranges": {
#         "quantiles": [
#           0.5,
#           0.75,
#           0.9,
#           0.95
#         ],
#         "value_ranges": [
#           [
#             null,
#             16.4
#           ],
#           [
#             null,
#             26.229166666666668
#           ],
#           [
#             null,
#             36.4375
#           ],
#           [
#             null,
#             42.0
#           ]
#         ]
#       }
#     },
#     "meta": {}
#   }
# ]>

# %% [markdown]
# **Verify that all expectations that we coded in our profiler are present here. Otherwise (if you can't find some expectations) it means that it failed to pass on the reference dataset (do it silently is default behavior of Great Expectations).**

# %% [markdown]
# ## Validating the features data against the validation rules - Successful scenario.

# %% [markdown]
# Now we can create validation reference from dataset and profiler function:

# %%
validation_reference = ds.as_reference(name="validation_reference_dataset", profiler=stats_profiler)

# %% [markdown]
# and test it against our existing retrieval job

# %%
try:
    _ = job.to_df(validation_reference=validation_reference)
    print("Data passed all the validation rules")
except ValidationFailed as exc:
    print("Data Failed some or all the validation rules")
    print(exc.validation_report)
# Out:
# Data passed all the validation rules

# %% [markdown]
# Validation successfully passed as no exception were raised. Features data adheres to the data validation rules.

# %% [markdown]
# ## Demonstrating the Validation Failure Use Case

# %% [markdown]
# In this section we will retrieve the historical features data which voilates the data characterstics defined in the previous step and hence throws the ValidationExeception

# %%
from feast.dqm.errors import ValidationFailed

# %%
timestamps = pd.DataFrame()
timestamps["event_timestamp"] = pd.date_range("2020-12-01", "2020-12-07", freq='D')

# %%
entity_df = pd.merge(taxi_ids, timestamps, how='cross')
entity_df
# Out:
#                                                  taxi_id event_timestamp
# 0      91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2020-12-01
# 1      91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2020-12-02
# 2      91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2020-12-03
# 3      91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2020-12-04
# 4      91d5288487e87c5917b813ba6f75ab1c3a9749af906a2d...      2020-12-05
# ...                                                  ...             ...
# 35443  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2020-12-03
# 35444  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2020-12-04
# 35445  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2020-12-05
# 35446  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2020-12-06
# 35447  7ebf27414a0c7b128e7925e1da56d51a8b81484f7630cf...      2020-12-07
#
# [35448 rows x 2 columns]

# %%
job = store.get_historical_features(
    entity_df=entity_df,
    features=[
        "trip_stats:total_miles_travelled",
        "trip_stats:total_trip_seconds",
        "trip_stats:total_earned",
        "trip_stats:trip_count",
        "on_demand_stats:avg_fare",
        "on_demand_stats:avg_trip_seconds",
        "on_demand_stats:avg_speed",
        "on_demand_stats:earned_per_hour",
    ]
)

# %%
try:
    df = job.to_df(validation_reference=validation_reference)
    print("Data passed all the validation rules")
except ValidationFailed as exc:
    print("Data Failed some or all the validation rules, exception report:")
    print("------------------------------------------------")
    print(exc.validation_report)
# Out:
# Data Failed some or all the validation rules, exception report:
# ------------------------------------------------
# [
#   {
#     "success": false,
#     "expectation_config": {
#       "expectation_type": "expect_column_mean_to_be_between",
#       "kwargs": {
#         "column": "trip_count",
#         "min_value": 10.387244591346153,
#         "max_value": 12.695521167200855,
#         "result_format": "COMPLETE"
#       },
#       "meta": {}
#     },
#     "result": {
#       "observed_value": 6.692920555429092,
#       "element_count": 4393,
#       "missing_count": null,
#       "missing_percent": null
#     },
#     "meta": {},
#     "exception_info": {
#       "raised_exception": false,
#       "exception_message": null,
#       "exception_traceback": null
#     }
#   },
#   {
#     "success": false,
#     "expectation_config": {
#       "expectation_type": "expect_column_mean_to_be_between",
#       "kwargs": {
#         "column": "earned_per_hour",
#         "min_value": 52.32062497564023,
#         "max_value": 63.9474305257825,
#         "result_format": "COMPLETE"
#       },
#       "meta": {}
#     },
#     "result": {
#       "observed_value": 68.99268345164135,
#       "element_count": 4393,
#       "missing_count": null,
#       "missing_percent": null
#     },
#     "meta": {},
#     "exception_info": {
#       "raised_exception": false,
#       "exception_message": null,
#       "exception_traceback": null
#     }
#   },
#   {
#     "success": false,
#     "expectation_config": {
#       "expectation_type": "expect_column_quantile_values_to_be_between",
#       "kwargs": {
#         "column": "avg_fare",
#         "quantile_ranges": {
#           "quantiles": [
#             0.5,
#             0.75,
#             0.9,
#             0.95
#           ],
#           "value_ranges": [
#             [
#               null,
#               16.4
#             ],
#             [
#               null,
#               26.229166666666668
#             ],
#             [
#               null,
#               36.4375
#             ],
#             [
#               null,
#               42.0
#             ]
#           ]
#         },
#         "result_format": "COMPLETE"
#       },
#       "meta": {}
#     },
#     "result": {
#       "observed_value": {
#         "quantiles": [
#           0.5,
#           0.75,
#           0.9,
#           0.95
#         ],
#         "values": [
#           19.5,
#           28.1,
#           38.0,
#           44.125
#         ]
#       },
#       "element_count": 4393,
#       "missing_count": null,
#       "missing_percent": null,
#       "details": {
#         "success_details": [
#           false,
#           false,
#           false,
#           false
#         ]
#       }
#     },
#     "meta": {},
#     "exception_info": {
#       "raised_exception": false,
#       "exception_message": null,
#       "exception_traceback": null
#     }
#   }
# ]

# %% [markdown]
# Validation failed since several expectations didn't pass:
#  - Trip count (mean) decreased more than 10% (which is expected when comparing Dec 2020 vs June 2019)
#  - Average Fare increased - all quantiles are higher than expected
#  - Earn per hour (mean) increased more than 10% (most probably due to increased fare)
